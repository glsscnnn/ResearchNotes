# %%
using NeuroFormats
using GLMakie

# some test data
mgh = read_mgh("3T/flash10.mgz")

volume = dropdims(mgh.data, dims=4)
axis = range(0, stop = 1, length = size(volume, 1))

contour(axis, axis, axis, volume, alpha=0.1, title="issa brain")
# Out:
# FigureAxisPlot()

# %%
using Printf

# damn brain real empty this one here lmao
for i = 1:256
    @printf "index %d: %.1f\n" i sum(volume[1:192, 1:192, i])
end
# Out:
# index 1: 0.0
# index 2: 0.0
# index 3: 0.0
# index 4: 0.0
# index 5: 0.0
# index 6: 0.0
# index 7: 0.0
# index 8: 0.0
# index 9: 0.0
# index 10: 0.0
# index 11: 0.0
# index 12: 0.0
# index 13: 0.0
# index 14: 0.0
# index 15: 0.0
# index 16: 0.0
# index 17: 0.0
# index 18: 0.0
# index 19: 0.0
# index 20: 0.0
# index 21: 0.0
# index 22: 0.0
# index 23: 0.0
# index 24: 0.0
# index 25: 0.0
# index 26: 0.0
# index 27: 0.0
# index 28: 0.0
# index 29: 0.0
# index 30: 0.0
# index 31: 0.0
# index 32: 0.0
# index 33: 0.0
# index 34: 0.0
# index 35: 0.0
# index 36: 0.0
# index 37: 0.0
# index 38: 0.0
# index 39: 0.0
# index 40: 0.0
# index 41: 0.0
# index 42: 0.0
# index 43: 0.0
# index 44: 0.0
# index 45: 0.0
# index 46: 0.0
# index 47: 0.0
# index 48: 0.0
# index 49: 7807.4
# index 50: 25434.1
# index 51: 67902.9
# index 52: 120687.4
# index 53: 173056.2
# index 54: 265650.6
# index 55: 303147.4
# index 56: 341428.0
# index 57: 384200.9
# index 58: 424555.3
# index 59: 462722.1
# ...

# %%
# each is a slice of the brain
contour(axis, axis, volume[1:192, 1:192, 106])
# Out:
# FigureAxisPlot()

# %%
contour(axis, axis, volume[1:192, 1:192, 110])
# Out:
# FigureAxisPlot()

# %%
contour(axis, axis, volume[1:192, 1:192, 111])
# Out:
# FigureAxisPlot()
